# %%
pip install wfdb
# Out:
# ...
#   Using cached wfdb-4.3.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached aiohttp-3.13.3-cp313-cp313-win_amd64.whl.metadata (8.4 kB)
# ...
#   Using cached matplotlib-3.10.8-cp313-cp313-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached soundfile-0.13.1-py2.py3-none-win_amd64.whl.metadata (16 kB)
# ...
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cffi-2.0.0-cp313-cp313-win_amd64.whl.metadata (2.6 kB)
# ...
# Using cached wfdb-4.3.1-py3-none-any.whl (163 kB)
# Using cached aiohttp-3.13.3-cp313-cp313-win_amd64.whl (453 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached matplotlib-3.10.8-cp313-cp313-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached soundfile-0.13.1-py2.py3-none-win_amd64.whl (1.0 MB)
# Using cached cffi-2.0.0-cp313-cp313-win_amd64.whl (183 kB)
# ...
#
# ...

# %%
import wfdb
record = wfdb.rdrecord("C:/Users/willi/Desktop/PTBXL/records100/00000/00030_lr")
record1 = wfdb.rdrecord("C:/Users/willi/Desktop/PTBXL/records500/00000/00030_hr")
print(record)
print(record1)

# %%
wfdb.plot_wfdb(record=record)
wfdb.plot_wfdb(record=record1)
